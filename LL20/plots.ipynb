# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df["%"].mean()
# Out:
# 0.40950346755867034

# %%
df["%"].mean()
# Out:
# 0.41172664453724567

# %%
df = pd.read_csv("results_error_free.csv")
df.plot.scatter(x = "double_matchings", y = "%", xlabel = "dobles coincidencias (double matchings)", ylabel = "fracción de bits recuperados", alpha = 0.5)

plt.savefig('LL20_results_error_free.svg', format = "svg")

# %%
df = pd.read_csv("results_error.csv")
df.plot.scatter(x = "double_matchings", y = "%", xlabel = "dobles coincidencias (double matchings)", ylabel = "fracción de bits recuperados", alpha = 0.5)

plt.savefig('LL20_results_error.svg', format = "svg")
