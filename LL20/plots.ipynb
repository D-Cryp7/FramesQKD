# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("results_error_free_with_time.csv")[:1000]
df.plot.scatter(x = "double_matchings", y = "%", xlabel = "double matchings", ylabel = "bits recovered ratio", alpha = 0.5, grid = True, marker = ".", s = 50)

plt.savefig('figures/LL20_results_error_free.svg', format = "svg")

# %%
df = pd.read_csv("results_error_free_with_time.csv")[:1000]
df.plot.scatter(x = "double_matchings", y = "time", xlabel = "double matchings", ylabel = "execution time (seconds)", alpha = 0.5, grid = True, marker = ".", color = "green", s = 50)

plt.savefig('figures/LL20_time_results_error_free.svg', format = "svg")

# %%
df = pd.read_csv("results_error_with_time.csv")[:1000]
df.plot.scatter(x = "double_matchings", y = "%", xlabel = "double matchings", ylabel = "bits recovered ratio", alpha = 0.5, grid = True, marker = ".", s = 50)

plt.savefig('figures/LL20_results_error.svg', format = "svg")

# %%
df = pd.read_csv("results_error_with_time.csv")[:1000]
df.plot.scatter(x = "double_matchings", y = "time", xlabel = "double matchings", ylabel = "execution time (seconds)", alpha = 0.5, grid = True, marker = ".", color = "green", s = 50)

plt.savefig('figures/LL20_time_results_error.svg', format = "svg")
